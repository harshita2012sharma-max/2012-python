# %%
#question-1 shop-->[pen,notebook,pizza,icecream,vadpav,football,jeans,shoes,shirt]
#filter out---->stationary---->[] sports--->[] bakery------>[] clothes--->[]
shop=["pen","notebook","pizza","icecream","vadpav","football","jeans","shoes","shirt"]
stationary = shop[0:2]
print(stationary)
bakery = shop[2:5]
print(bakery)
sports = shop[5:6]
print(sports)
clothes=shop[6:]
print(clothes)
# Out:
# ['pen', 'notebook']
# ['pizza', 'icecream', 'vadpav']
# ['football']
# ['jeans', 'shoes', 'shirt']

# %%
#question-3 extract top 3 longest word.
a=['python','data','science','machine','ai','development']
list=[i for i in range i]
# Out:
#   Cell In[41], line 3
#     list=[i for i in range i.sort()]
#                            ^
# SyntaxError: invalid syntax

# %%
#question-5
a=['py@thon','d#ata','science']
a = ['py@thon', 'd#ata', 'sc!ience']
cleaned = []

# for i in a:
#     new_word = ""
#     for ch in i:
#         if ch.isalnum():
#             new_word += ch
#     cleaned.append(new_word)

# print(cleaned)
                       #or
# Out:
# ['python', 'data', 'science']

# %%
#question-2
tuple=[(x,x**2) for x in range(1,6)]
tuple
# Out:
# [(1, 1), (2, 4), (3, 9), (4, 16), (5, 25)]

# %%
#4
a=['9567465691','875672373','2345','9579']
valid_number=[i for i in a if len(i)==10]
valid_number
# Out:
# ['9567465691']

# %%
txt = "hellowor\tld"
print(txt.expandtabs(6))   # "hello    world"
# Out:
# hellowor    ld

# %%
txt="@123?!"
print(txt.strip("?!@"))
# Out:
# 123

# %%
a=20
b=21
#print(a or b)
print(a|b)
# Out:
# 21

# %%
a=20
b=21
print(a and b)
print(a&b)
# Out:
# 21
# 20
