# %%
#create a tuple of square from 1 to 4?
a=tuple(i**2 for i in range(1,5))
a
# Out:
# (1, 4, 9, 16)

# %%
#2.
a=tuple(i**2 for i in range(1,10) if i%2==0)
a
# Out:
# (4, 16, 36, 64)

# %%
a=tuple('even' if x%2==0 else 'odd' for x in range(1,11))
a
# Out:
# ('odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even')

# %%
#3 from the string "python" create a tuple that convert vowel to upper case and consonant to lower case.
a="consonant"
b=tuple(i.upper() if i.lower() in "aeiou" else i.lower() for i in a )
print(b)
# Out:
# ('c', 'O', 'n', 's', 'O', 'n', 'A', 'n', 't')

# %%
#4 create a tuple where number divible by 3 are "Div3" otherwise keep the number
a=tuple("Div3" if i%3==0 else i for i in range(1,11))
a
# Out:
# (1, 2, 'Div3', 4, 5, 'Div3', 7, 8, 'Div3', 10)

# %%
a=tuple('even' if x%2==0 else 'odd' for x in range(1,11))
a
# Out:
# ('odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even')

# %%
#4 generate a tuple of (number,square) pairs for numbers from 1 to 6
a=tuple((i,i**2) for i in range(1,6))
a
# Out:
# ((1, 1), (2, 4), (3, 9), (4, 16), (5, 25))

# %%
a="Mathematics is good"
a=a.split()
print(a)
first=tuple(i[0] for i in a)
first
# Out:
# ['Mathematics', 'is', 'good']
# ('M', 'i', 'g')

# %%
#8 create a tupple of squares of numbers
a=tuple(i**2 for i in range (1,10 )if i**2>5)
a
# Out:
# (9, 16, 25, 36, 49, 64, 81)

# %%
a=tuple("Three" if i%3==0 else "Five" if i%5==0 else i for i in range(1,9))
a
# Out:
# (1, 2, 'Three', 4, 'Five', 'Three', 7, 8)

# %%
# form a list of names we have to create a tuple of names uppercase if length is greater than 4 otherwise lowercase
names=["AI","Python","ML","Science"]
output=tuple(i.upper() if len(i)>4 else i.lower() for i in names)
output
# Out:
# ('ai', 'PYTHON', 'ml', 'SCIENCE')

# %%
# from the word developer create a tuple of only vowels
word="developEr"
word_1=tuple(i for i in word if i.lower() in "aeiou")
word_1
# Out:
# ('e', 'e', 'o', 'E')

# %%
#create a tupleof word pairs for each word in sentence.word_1
a="Python tuple comprehension practice"
a=a.split()
b=tuple((i,len(i)) for i in a)
b
# Out:
# (('Python', 6), ('tuple', 5), ('comprehension', 13), ('practice', 8))
