# %%
#question-1
with open('hello.txt','w') as hllo:
    hllo.write("hello, python!")

# %%
#questionn-2
file=open('hello.txt','r')
data=file.read(3)
print(data)

with open('hello.txt','r') as hllo:
    print(hllo.read(5))
# Out:
# hel
# hello

# %%
#question-3
with open('hello.txt','a')as hllo:
    hllo.write("\nWelcome to python.")

# %%
#question-4
with open('hello.txt','r') as hllo:
    print(hllo.read(10))
# Out:
# hello, pyt

# %%
#question-5
with open('hello.txt','r') as hllo:
    print(hllo.readlines())
# Out:
# ['hello, python!\n', ' Welcome to python.\n', 'Welcome to python.']

# %%
#question-6
with open('hello.txt','r') as hllo:
    with open('copy.txt','w') as cpy:
        for lines in hllo:
            cpy.write(lines)

# %%
#question-7
lst=[1,2,3,4,5]
with open('hello.txt','w') as hllo:
    for numbers in lst:
        hllo.write(str(numbers)+'\n')

# %%
#question-8
total=0
with open('hello.txt','r') as hllo:
    for numbers in hllo:
        total+=int(numbers.strip())
print("sum of numbers",total)
# Out:
# sum of numbers 15

# %%
#question-9
with open('copy.txt','r') as cpy:
    content=cpy.read()
updated_content=content.replace("python","programming")

with open('copy.txt','w') as cpy:
    cpy.write(updated_content)
print("replacing succesfull")
# Out:
# replacing succesfull

# %%
#question-10
with open('hello.txt','r') as f1:
    content1=f1.read()

with open('copy.txt','r') as f2:
    content2=f2.read()

with open('merged.txt','w') as merged:
    merged.write(content1+'\n'+content2)
